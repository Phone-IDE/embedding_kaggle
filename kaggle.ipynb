# %%
# !sudo apt install pciutils
# !sudo apt install lshw
# !pip install requests 
# !pip install "xinference[transformers]"
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libpci3 pci.ids
# The following NEW packages will be installed:
#   libpci3 pci.ids pciutils
# 0 upgraded, 3 newly installed, 0 to remove and 129 not upgraded.
# Need to get 343 kB of archives.
# After this operation, 1,581 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 pci.ids all 0.0~2022.01.22-1 [251 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libpci3 amd64 1:3.7.0-6 [28.9 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 pciutils amd64 1:3.7.0-6 [63.6 kB]
# Fetched 343 kB in 1s (403 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 3.)
# debconf: falling back to frontend: Readline
#
# 78Selecting previously unselected package pci.ids.
# (Reading database ... 127400 files and directories currently installed.)
# Preparing to unpack .../pci.ids_0.0~2022.01.22-1_all.deb ...
# 7Progress: [  0%] [..........................................................] 87Progress: [  8%] [####......................................................] 8Unpacking pci.ids (0.0~2022.01.22-1) ...
# 7Progress: [ 15%] [########..................................................] 8Selecting previously unselected package libpci3:amd64.
# Preparing to unpack .../libpci3_1%3a3.7.0-6_amd64.deb ...
# 7Progress: [ 23%] [#############.............................................] 8Unpacking libpci3:amd64 (1:3.7.0-6) ...
# 7Progress: [ 31%] [#################.........................................] 8Selecting previously unselected package pciutils.
# Preparing to unpack .../pciutils_1%3a3.7.0-6_amd64.deb ...
# 7Progress: [ 38%] [######################....................................] 8Unpacking pciutils (1:3.7.0-6) ...
# 7Progress: [ 46%] [##########################................................] 8Setting up pci.ids (0.0~2022.01.22-1) ...
# 7Progress: [ 54%] [###############################...........................] 87Progress: [ 62%] [###################################.......................] 8Setting up libpci3:amd64 (1:3.7.0-6) ...
# 7Progress: [ 69%] [########################################..................] 87Progress: [ 77%] [############################################..............] 8Setting up pciutils (1:3.7.0-6) ...
# 7Progress: [ 85%] [#################################################.........] 87Progress: [ 92%] [#####################################################.....] 8Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
#
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   usb.ids
# The following NEW packages will be installed:
#   lshw usb.ids
# 0 upgraded, 2 newly installed, 0 to remove and 129 not upgraded.
# Need to get 540 kB of archives.
# After this operation, 1,675 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 lshw amd64 02.19.git.2021.06.19.996aaad9c7-2build1 [321 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 usb.ids all 2022.04.02-1 [219 kB]
# Fetched 540 kB in 0s (1,972 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 2.)
# debconf: falling back to frontend: Readline
#
# 78Selecting previously unselected package lshw.
# (Reading database ... 127422 files and directories currently installed.)
# Preparing to unpack .../lshw_02.19.git.2021.06.19.996aaad9c7-2build1_amd64.deb ...
# 7Progress: [  0%] [..........................................................] 87Progress: [ 11%] [######....................................................] 8Unpacking lshw (02.19.git.2021.06.19.996aaad9c7-2build1) ...
# 7Progress: [ 22%] [############..............................................] 8Selecting previously unselected package usb.ids.
# Preparing to unpack .../usb.ids_2022.04.02-1_all.deb ...
# 7Progress: [ 33%] [###################.......................................] 8Unpacking usb.ids (2022.04.02-1) ...
# 7Progress: [ 44%] [#########################.................................] 8Setting up lshw (02.19.git.2021.06.19.996aaad9c7-2build1) ...
# 7Progress: [ 56%] [################################..........................] 87Progress: [ 67%] [######################################....................] 8Setting up usb.ids (2022.04.02-1) ...
# 7Progress: [ 78%] [#############################################.............] 87Progress: [ 89%] [###################################################.......] 8Processing triggers for man-db (2.10.2-1) ...
#
# 78Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2025.1.31)
# Collecting xinference[transformers]
#   Downloading xinference-1.4.0-py3-none-any.whl.metadata (24 kB)
# Collecting xoscar>=0.4.4 (from xinference[transformers])
#   Downloading xoscar-0.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.0 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from xinference[transformers]) (2.5.1+cu121)
# Collecting gradio (from xinference[transformers])
#   Downloading gradio-5.23.3-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from xinference[transformers]) (11.0.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from xinference[transformers]) (8.1.7)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from xinference[transformers]) (4.67.1)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from xinference[transformers]) (0.9.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from xinference[transformers]) (2.32.3)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.10/dist-packages (from xinference[transformers]) (2.11.0a2)
# Collecting fastapi>=0.110.3 (from xinference[transformers])
#   Downloading fastapi-0.115.12-py3-none-any.whl.metadata (27 kB)
# Collecting uvicorn (from xinference[transformers])
#   Downloading uvicorn-0.34.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: huggingface-hub>=0.19.4 in /usr/local/lib/python3.10/dist-packages (from xinference[transformers]) (0.29.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from xinference[transformers]) (4.12.2)
# Collecting modelscope>=1.10.0 (from xinference[transformers])
#   Downloading modelscope-1.24.1-py3-none-any.whl.metadata (39 kB)
# Collecting sse-starlette>=1.6.5 (from xinference[transformers])
#   Downloading sse_starlette-2.2.1-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: openai>=1.40.0 in /usr/local/lib/python3.10/dist-packages (from xinference[transformers]) (1.57.4)
# Collecting python-jose[cryptography] (from xinference[transformers])
#   Downloading python_jose-3.4.0-py2.py3-none-any.whl.metadata (5.5 kB)
# Collecting passlib[bcrypt] (from xinference[transformers])
#   Downloading passlib-1.7.4-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting aioprometheus>=23.12.0 (from aioprometheus[starlette]>=23.12.0->xinference[transformers])
#   Downloading aioprometheus-23.12.0-py3-none-any.whl.metadata (9.8 kB)
# Requirement already satisfied: nvidia-ml-py in /usr/local/lib/python3.10/dist-packages (from xinference[transformers]) (12.570.86)
# Requirement already satisfied: pynvml>=12 in /usr/local/lib/python3.10/dist-packages (from xinference[transformers]) (12.0.0)
# Requirement already satisfied: async-timeout in /usr/local/lib/python3.10/dist-packages (from xinference[transformers]) (5.0.1)
# Requirement already satisfied: peft in /usr/local/lib/python3.10/dist-packages (from xinference[transformers]) (0.14.0)
# Requirement already satisfied: timm in /usr/local/lib/python3.10/dist-packages (from xinference[transformers]) (1.0.12)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.10/dist-packages (from xinference[transformers]) (1.3.4)
# Requirement already satisfied: transformers>=4.46.0 in /usr/local/lib/python3.10/dist-packages (from xinference[transformers]) (4.47.0)
# Requirement already satisfied: accelerate>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from xinference[transformers]) (1.2.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from xinference[transformers]) (0.2.0)
# Collecting transformers-stream-generator (from xinference[transformers])
#   Downloading transformers-stream-generator-0.0.5.tar.gz (13 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from xinference[transformers]) (3.20.3)
# Requirement already satisfied: einops in /usr/local/lib/python3.10/dist-packages (from xinference[transformers]) (0.8.0)
# Requirement already satisfied: tiktoken in /usr/local/lib/python3.10/dist-packages (from xinference[transformers]) (0.9.0)
# Collecting optimum (from xinference[transformers])
#   Downloading optimum-1.24.0-py3-none-any.whl.metadata (21 kB)
# Collecting attrdict (from xinference[transformers])
#   Downloading attrdict-2.0.1-py2.py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from xinference[transformers]) (0.20.1+cu121)
# Collecting eva-decord (from xinference[transformers])
#   Downloading eva_decord-0.6.1-py3-none-manylinux2010_x86_64.whl.metadata (449 bytes)
# Collecting jj-pytorchvideo (from xinference[transformers])
#   Downloading jj_pytorchvideo-0.1.5-py3-none-any.whl.metadata (1.2 kB)
# Collecting qwen-vl-utils!=0.0.9 (from xinference[transformers])
#   Downloading qwen_vl_utils-0.0.10-py3-none-any.whl.metadata (6.3 kB)
# Collecting datamodel-code-generator (from xinference[transformers])
#   Downloading datamodel_code_generator-0.28.5-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.10/dist-packages (from xinference[transformers]) (4.23.0)
# Requirement already satisfied: blobfile in /usr/local/lib/python3.10/dist-packages (from xinference[transformers]) (3.0.0)
# Collecting auto-gptq (from xinference[transformers])
#   Downloading auto_gptq-0.7.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Collecting autoawq<0.2.6 (from xinference[transformers])
#   Downloading autoawq-0.2.5-cp310-cp310-manylinux2014_x86_64.whl.metadata (16 kB)
# Collecting bitsandbytes (from xinference[transformers])
#   Downloading bitsandbytes-0.45.4-py3-none-manylinux_2_24_x86_64.whl.metadata (5.0 kB)
# Requirement already satisfied: numpy<3.0.0,>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.28.0->xinference[transformers]) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.28.0->xinference[transformers]) (24.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.28.0->xinference[transformers]) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.28.0->xinference[transformers]) (6.0.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.28.0->xinference[transformers]) (0.4.5)
# Requirement already satisfied: orjson in /usr/local/lib/python3.10/dist-packages (from aioprometheus>=23.12.0->aioprometheus[starlette]>=23.12.0->xinference[transformers]) (3.10.12)
# Collecting quantile-python>=1.1 (from aioprometheus>=23.12.0->aioprometheus[starlette]>=23.12.0->xinference[transformers])
#   Downloading quantile-python-1.1.tar.gz (2.9 kB)
#   Preparing metadata (setup.py) ... done
# Collecting starlette>=0.14.2 (from aioprometheus[starlette]>=23.12.0->xinference[transformers])
#   Downloading starlette-0.46.1-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: tokenizers>=0.12.1 in /usr/local/lib/python3.10/dist-packages (from autoawq<0.2.6->xinference[transformers]) (0.21.0)
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (from autoawq<0.2.6->xinference[transformers]) (3.3.1)
# Collecting zstandard (from autoawq<0.2.6->xinference[transformers])
#   Downloading zstandard-0.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Collecting autoawq-kernels (from autoawq<0.2.6->xinference[transformers])
#   Downloading autoawq_kernels-0.0.9-cp310-cp310-manylinux2014_x86_64.whl.metadata (2.4 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.4->xinference[transformers]) (3.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.4->xinference[transformers]) (2024.12.0)
# Requirement already satisfied: urllib3>=1.26 in /usr/local/lib/python3.10/dist-packages (from modelscope>=1.10.0->xinference[transformers]) (2.3.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai>=1.40.0->xinference[transformers]) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from openai>=1.40.0->xinference[transformers]) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from openai>=1.40.0->xinference[transformers]) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from openai>=1.40.0->xinference[transformers]) (0.8.2)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai>=1.40.0->xinference[transformers]) (1.3.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic->xinference[transformers]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.29.0 in /usr/local/lib/python3.10/dist-packages (from pydantic->xinference[transformers]) (2.29.0)
# Collecting av (from qwen-vl-utils!=0.0.9->xinference[transformers])
#   Downloading av-14.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->xinference[transformers]) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->xinference[transformers]) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->xinference[transformers]) (2025.1.31)
# Collecting anyio<5,>=3.5.0 (from openai>=1.40.0->xinference[transformers])
#   Downloading anyio-4.9.0-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->xinference[transformers]) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->xinference[transformers]) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch->xinference[transformers]) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch->xinference[transformers]) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.46.0->xinference[transformers]) (2024.11.6)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from xoscar>=0.4.4->xinference[transformers]) (2.2.3)
# Requirement already satisfied: cloudpickle>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from xoscar>=0.4.4->xinference[transformers]) (3.1.0)
# Requirement already satisfied: tblib>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from xoscar>=0.4.4->xinference[transformers]) (3.0.0)
# Collecting uvloop>=0.14.0 (from xoscar>=0.4.4->xinference[transformers])
#   Downloading uvloop-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from xoscar>=0.4.4->xinference[transformers]) (1.13.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from attrdict->xinference[transformers]) (1.17.0)
# Collecting rouge (from auto-gptq->xinference[transformers])
#   Downloading rouge-1.0.1-py3-none-any.whl.metadata (4.1 kB)
# Collecting gekko (from auto-gptq->xinference[transformers])
#   Downloading gekko-1.3.0-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: pycryptodomex>=3.8 in /usr/local/lib/python3.10/dist-packages (from blobfile->xinference[transformers]) (3.21.0)
# Requirement already satisfied: lxml>=4.9 in /usr/local/lib/python3.10/dist-packages (from blobfile->xinference[transformers]) (5.3.0)
# Collecting argcomplete<4,>=2.10.1 (from datamodel-code-generator->xinference[transformers])
#   Downloading argcomplete-3.6.2-py3-none-any.whl.metadata (16 kB)
# Collecting black>=19.10b0 (from datamodel-code-generator->xinference[transformers])
#   Downloading black-25.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl.metadata (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.3/81.3 kB 4.2 MB/s eta 0:00:00
# Collecting genson<2,>=1.2.1 (from datamodel-code-generator->xinference[transformers])
#   Downloading genson-1.3.0-py3-none-any.whl.metadata (28 kB)
# Collecting inflect<6,>=4.1 (from datamodel-code-generator->xinference[transformers])
#   Downloading inflect-5.6.2-py3-none-any.whl.metadata (21 kB)
# Collecting isort<7,>=4.3.21 (from datamodel-code-generator->xinference[transformers])
#   Downloading isort-6.0.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: tomli<3,>=2.2.1 in /usr/local/lib/python3.10/dist-packages (from datamodel-code-generator->xinference[transformers]) (2.2.1)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in /usr/local/lib/python3.10/dist-packages (from gradio->xinference[transformers]) (22.1.0)
# Collecting ffmpy (from gradio->xinference[transformers])
#   Downloading ffmpy-0.5.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting gradio-client==1.8.0 (from gradio->xinference[transformers])
#   Downloading gradio_client-1.8.0-py3-none-any.whl.metadata (7.1 kB)
# Collecting groovy~=0.1 (from gradio->xinference[transformers])
#   Downloading groovy-0.1.2-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio->xinference[transformers]) (3.0.2)
# Requirement already satisfied: pydub in /usr/local/lib/python3.10/dist-packages (from gradio->xinference[transformers]) (0.25.1)
# Collecting python-multipart>=0.0.18 (from gradio->xinference[transformers])
#   Downloading python_multipart-0.0.20-py3-none-any.whl.metadata (1.8 kB)
# Collecting ruff>=0.9.3 (from gradio->xinference[transformers])
#   Downloading ruff-0.11.2-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (25 kB)
# Collecting safehttpx<0.2.0,>=0.1.6 (from gradio->xinference[transformers])
#   Downloading safehttpx-0.1.6-py3-none-any.whl.metadata (4.2 kB)
# Collecting semantic-version~=2.0 (from gradio->xinference[transformers])
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting tomlkit<0.14.0,>=0.12.0 (from gradio->xinference[transformers])
#   Downloading tomlkit-0.13.2-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.10/dist-packages (from gradio->xinference[transformers]) (0.15.1)
# Requirement already satisfied: websockets<16.0,>=10.0 in /usr/local/lib/python3.10/dist-packages (from gradio-client==1.8.0->gradio->xinference[transformers]) (14.1)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.10/dist-packages (from uvicorn->xinference[transformers]) (0.14.0)
# Collecting fvcore (from jj-pytorchvideo->xinference[transformers])
#   Downloading fvcore-0.1.5.post20221221.tar.gz (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 2.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting parameterized (from jj-pytorchvideo->xinference[transformers])
#   Downloading parameterized-0.9.0-py2.py3-none-any.whl.metadata (18 kB)
# Collecting iopath (from jj-pytorchvideo->xinference[transformers])
#   Downloading iopath-0.1.10.tar.gz (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 2.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema->xinference[transformers]) (25.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema->xinference[transformers]) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema->xinference[transformers]) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema->xinference[transformers]) (0.22.3)
# Collecting bcrypt>=3.1.0 (from passlib[bcrypt]->xinference[transformers])
#   Downloading bcrypt-4.3.0-cp39-abi3-manylinux_2_34_x86_64.whl.metadata (10 kB)
# Collecting ecdsa!=0.15 (from python-jose[cryptography]->xinference[transformers])
#   Downloading ecdsa-0.19.1-py2.py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: rsa!=4.1.1,!=4.4,<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from python-jose[cryptography]->xinference[transformers]) (4.9)
# Collecting pyasn1<0.5.0,>=0.4.1 (from python-jose[cryptography]->xinference[transformers])
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: cryptography>=3.4.0 in /usr/local/lib/python3.10/dist-packages (from python-jose[cryptography]->xinference[transformers]) (44.0.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai>=1.40.0->xinference[transformers]) (1.2.2)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /usr/local/lib/python3.10/dist-packages (from black>=19.10b0->datamodel-code-generator->xinference[transformers]) (1.0.0)
# Collecting pathspec>=0.9.0 (from black>=19.10b0->datamodel-code-generator->xinference[transformers])
#   Downloading pathspec-0.12.1-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: platformdirs>=2 in /usr/local/lib/python3.10/dist-packages (from black>=19.10b0->datamodel-code-generator->xinference[transformers]) (4.3.6)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=3.4.0->python-jose[cryptography]->xinference[transformers]) (1.17.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai>=1.40.0->xinference[transformers]) (1.0.7)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy<3.0.0,>=1.17->accelerate>=0.28.0->xinference[transformers]) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy<3.0.0,>=1.17->accelerate>=0.28.0->xinference[transformers]) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy<3.0.0,>=1.17->accelerate>=0.28.0->xinference[transformers]) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy<3.0.0,>=1.17->accelerate>=0.28.0->xinference[transformers]) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy<3.0.0,>=1.17->accelerate>=0.28.0->xinference[transformers]) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy<3.0.0,>=1.17->accelerate>=0.28.0->xinference[transformers]) (2.4.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.0->xoscar>=0.4.4->xinference[transformers]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.0->xoscar>=0.4.4->xinference[transformers]) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.0->xoscar>=0.4.4->xinference[transformers]) (2025.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0,>=0.12->gradio->xinference[transformers]) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0,>=0.12->gradio->xinference[transformers]) (13.9.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets->autoawq<0.2.6->xinference[transformers]) (19.0.1)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets->autoawq<0.2.6->xinference[transformers]) (0.3.8)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets->autoawq<0.2.6->xinference[transformers]) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.10/dist-packages (from datasets->autoawq<0.2.6->xinference[transformers]) (0.70.16)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets->autoawq<0.2.6->xinference[transformers]) (3.11.12)
# Collecting yacs>=0.1.6 (from fvcore->jj-pytorchvideo->xinference[transformers])
#   Downloading yacs-0.1.8-py3-none-any.whl.metadata (639 bytes)
# Requirement already satisfied: termcolor>=1.1 in /usr/local/lib/python3.10/dist-packages (from fvcore->jj-pytorchvideo->xinference[transformers]) (2.5.0)
# Collecting portalocker (from iopath->jj-pytorchvideo->xinference[transformers])
#   Downloading portalocker-3.1.1-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=3.4.0->python-jose[cryptography]->xinference[transformers]) (2.22)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->autoawq<0.2.6->xinference[transformers]) (2.4.6)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->autoawq<0.2.6->xinference[transformers]) (1.3.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->autoawq<0.2.6->xinference[transformers]) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->autoawq<0.2.6->xinference[transformers]) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->autoawq<0.2.6->xinference[transformers]) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->autoawq<0.2.6->xinference[transformers]) (1.18.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio->xinference[transformers]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio->xinference[transformers]) (2.19.1)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy<3.0.0,>=1.17->accelerate>=0.28.0->xinference[transformers]) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy<3.0.0,>=1.17->accelerate>=0.28.0->xinference[transformers]) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy<3.0.0,>=1.17->accelerate>=0.28.0->xinference[transformers]) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy<3.0.0,>=1.17->accelerate>=0.28.0->xinference[transformers]) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy<3.0.0,>=1.17->accelerate>=0.28.0->xinference[transformers]) (2024.2.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio->xinference[transformers]) (0.1.2)
# Downloading aioprometheus-23.12.0-py3-none-any.whl (31 kB)
# Downloading autoawq-0.2.5-cp310-cp310-manylinux2014_x86_64.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.3/84.3 kB 4.6 MB/s eta 0:00:00
# Downloading fastapi-0.115.12-py3-none-any.whl (95 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.2/95.2 kB 4.9 MB/s eta 0:00:00
# Downloading modelscope-1.24.1-py3-none-any.whl (5.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 66.5 MB/s eta 0:00:00:00:010:01
# Downloading qwen_vl_utils-0.0.10-py3-none-any.whl (6.7 kB)
# Downloading sse_starlette-2.2.1-py3-none-any.whl (10 kB)
# Downloading xoscar-0.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 89.2 MB/s eta 0:00:00:00:01
# Downloading attrdict-2.0.1-py2.py3-none-any.whl (9.9 kB)
# Downloading auto_gptq-0.7.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.5/23.5 MB 80.9 MB/s eta 0:00:00:00:0100:01
# Downloading bitsandbytes-0.45.4-py3-none-manylinux_2_24_x86_64.whl (76.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.0/76.0 MB 22.5 MB/s eta 0:00:00:00:0100:01
# Downloading datamodel_code_generator-0.28.5-py3-none-any.whl (117 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.3/117.3 kB 6.0 MB/s eta 0:00:00
# Downloading eva_decord-0.6.1-py3-none-manylinux2010_x86_64.whl (13.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.6/13.6 MB 92.0 MB/s eta 0:00:00:00:0100:01
# Downloading gradio-5.23.3-py3-none-any.whl (46.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.5/46.5 MB 37.5 MB/s eta 0:00:00:00:0100:01
# Downloading gradio_client-1.8.0-py3-none-any.whl (322 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.2/322.2 kB 17.7 MB/s eta 0:00:00
# Downloading uvicorn-0.34.0-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 3.5 MB/s eta 0:00:00
# Downloading jj_pytorchvideo-0.1.5-py3-none-any.whl (213 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.1/213.1 kB 14.1 MB/s eta 0:00:00
# Downloading optimum-1.24.0-py3-none-any.whl (433 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 433.6/433.6 kB 19.9 MB/s eta 0:00:00
# Downloading xinference-1.4.0-py3-none-any.whl (33.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.2/33.2 MB 53.3 MB/s eta 0:00:00:00:0100:01
# Downloading anyio-4.9.0-py3-none-any.whl (100 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.9/100.9 kB 5.8 MB/s eta 0:00:00
# Downloading argcomplete-3.6.2-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 2.5 MB/s eta 0:00:00
# Downloading bcrypt-4.3.0-cp39-abi3-manylinux_2_34_x86_64.whl (284 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 284.2/284.2 kB 17.7 MB/s eta 0:00:00
# Downloading black-25.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 55.7 MB/s eta 0:00:00
# Downloading ecdsa-0.19.1-py2.py3-none-any.whl (150 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.6/150.6 kB 8.6 MB/s eta 0:00:00
# Downloading genson-1.3.0-py3-none-any.whl (21 kB)
# Downloading groovy-0.1.2-py3-none-any.whl (14 kB)
# Downloading inflect-5.6.2-py3-none-any.whl (33 kB)
# Downloading isort-6.0.1-py3-none-any.whl (94 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.2/94.2 kB 4.2 MB/s eta 0:00:00
# Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.1/77.1 kB 4.1 MB/s eta 0:00:00
# Downloading python_multipart-0.0.20-py3-none-any.whl (24 kB)
# Downloading ruff-0.11.2-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 100.5 MB/s eta 0:00:0000:010:01
# Downloading safehttpx-0.1.6-py3-none-any.whl (8.7 kB)
# Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Downloading starlette-0.46.1-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 4.1 MB/s eta 0:00:00
# Downloading tomlkit-0.13.2-py3-none-any.whl (37 kB)
# Downloading uvloop-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 72.4 MB/s eta 0:00:00:00:01
# Downloading autoawq_kernels-0.0.9-cp310-cp310-manylinux2014_x86_64.whl (37.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.4/37.4 MB 47.4 MB/s eta 0:00:00:00:0100:01
# Downloading av-14.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.8/38.8 MB 46.3 MB/s eta 0:00:00:00:0100:01
# Downloading ffmpy-0.5.0-py3-none-any.whl (6.0 kB)
# Downloading gekko-1.3.0-py3-none-any.whl (13.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 99.6 MB/s eta 0:00:00:00:010:01
# Downloading parameterized-0.9.0-py2.py3-none-any.whl (20 kB)
# Downloading passlib-1.7.4-py2.py3-none-any.whl (525 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 525.6/525.6 kB 19.6 MB/s eta 0:00:00
# Downloading python_jose-3.4.0-py2.py3-none-any.whl (34 kB)
# Downloading rouge-1.0.1-py3-none-any.whl (13 kB)
# Downloading zstandard-0.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 88.4 MB/s eta 0:00:00:00:01
# Downloading pathspec-0.12.1-py3-none-any.whl (31 kB)
# Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Downloading portalocker-3.1.1-py3-none-any.whl (19 kB)
# Building wheels for collected packages: transformers-stream-generator, quantile-python, fvcore, iopath
#   Building wheel for transformers-stream-generator (setup.py) ... done
#   Created wheel for transformers-stream-generator: filename=transformers_stream_generator-0.0.5-py3-none-any.whl size=12425 sha256=dc8870669c767ac2bb1395f66339837f49993289f834b22e5f4bd205c5aaae5d
#   Stored in directory: /root/.cache/pip/wheels/95/4a/90/140f7b67d125906f6a165f38aad212ecb4a695ad0d87582437
#   Building wheel for quantile-python (setup.py) ... done
#   Created wheel for quantile-python: filename=quantile_python-1.1-py3-none-any.whl size=3445 sha256=fb0aa2be34d6dd0a76afcf10fbbc2a6a7ef7db70dae7a83590dd02fba836581d
#   Stored in directory: /root/.cache/pip/wheels/6d/f4/0a/0e7d01548a005f9f3fa23101f071d248da052f2a9bf2fe11c6
#   Building wheel for fvcore (setup.py) ... done
#   Created wheel for fvcore: filename=fvcore-0.1.5.post20221221-py3-none-any.whl size=61396 sha256=7c687d2244c93d99f81871f5f9af9132143619e68c55504aa8639978aeaff4c6
#   Stored in directory: /root/.cache/pip/wheels/01/c0/af/77c1cf53a1be9e42a52b48e5af2169d40ec2e89f7362489dd0
#   Building wheel for iopath (setup.py) ... done
#   Created wheel for iopath: filename=iopath-0.1.10-py3-none-any.whl size=31528 sha256=23f8847f52159363548c5d419e2c393f330e964ea0676af7f0e3745e964b9d3c
#   Stored in directory: /root/.cache/pip/wheels/9a/a3/b6/ac0fcd1b4ed5cfeb3db92e6a0e476cfd48ed0df92b91080c1d
# Successfully built transformers-stream-generator quantile-python fvcore iopath
# Installing collected packages: quantile-python, pyasn1, passlib, genson, zstandard, yacs, uvloop, uvicorn, tomlkit, semantic-version, ruff, rouge, python-multipart, portalocker, pathspec, parameterized, isort, inflect, groovy, ffmpy, ecdsa, bcrypt, av, attrdict, argcomplete, anyio, aioprometheus, starlette, qwen-vl-utils, python-jose, modelscope, iopath, black, sse-starlette, safehttpx, gradio-client, fastapi, datamodel-code-generator, autoawq-kernels, xoscar, gradio, gekko, fvcore, xinference, transformers-stream-generator, optimum, jj-pytorchvideo, eva-decord, bitsandbytes, autoawq, auto-gptq
#   Attempting uninstall: pyasn1
#     Found existing installation: pyasn1 0.6.1
#     Uninstalling pyasn1-0.6.1:
#       Successfully uninstalled pyasn1-0.6.1
#   Attempting uninstall: inflect
#     Found existing installation: inflect 7.4.0
#     Uninstalling inflect-7.4.0:
#       Successfully uninstalled inflect-7.4.0
#   Attempting uninstall: anyio
#     Found existing installation: anyio 3.7.1
#     Uninstalling anyio-3.7.1:
#       Successfully uninstalled anyio-3.7.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sigstore 3.6.1 requires pyasn1~=0.6, but you have pyasn1 0.4.8 which is incompatible.
# Successfully installed aioprometheus-23.12.0 anyio-4.9.0 argcomplete-3.6.2 attrdict-2.0.1 auto-gptq-0.7.1 autoawq-0.2.5 autoawq-kernels-0.0.9 av-14.2.0 bcrypt-4.3.0 bitsandbytes-0.45.4 black-25.1.0 datamodel-code-generator-0.28.5 ecdsa-0.19.1 eva-decord-0.6.1 fastapi-0.115.12 ffmpy-0.5.0 fvcore-0.1.5.post20221221 gekko-1.3.0 genson-1.3.0 gradio-5.23.3 gradio-client-1.8.0 groovy-0.1.2 inflect-5.6.2 iopath-0.1.10 isort-6.0.1 jj-pytorchvideo-0.1.5 modelscope-1.24.1 optimum-1.24.0 parameterized-0.9.0 passlib-1.7.4 pathspec-0.12.1 portalocker-3.1.1 pyasn1-0.4.8 python-jose-3.4.0 python-multipart-0.0.20 quantile-python-1.1 qwen-vl-utils-0.0.10 rouge-1.0.1 ruff-0.11.2 safehttpx-0.1.6 semantic-version-2.10.0 sse-starlette-2.2.1 starlette-0.46.1 tomlkit-0.13.2 transformers-stream-generator-0.0.5 uvicorn-0.34.0 uvloop-0.21.0 xinference-1.4.0 xoscar-0.5.0 yacs-0.1.8 zstandard-0.23.0

# %%
import requests
import os
import zipfile
import tarfile
import subprocess
import os
import threading
import time
import signal
import sys
import stat
import subprocess

class AutoFrp():

    def __init__(self,auto_frp_backend_url:str,platform:str):
        self.auto_frp_backend_url = auto_frp_backend_url
        self.platform = platform
        
    def download_config(self, port: int, output_path: str = "./", remote_port: int = None):
        """
        从AutoFrp服务器下载frpc配置和二进制文件
        
        Args:
            port: 本地要映射的端口
            output_path: 保存下载文件的路径
            remote_port: 可选的远程端口，如果不指定则由服务器随机分配
        
        Returns:
            str: 保存的文件路径
        """

        if not os.path.exists(output_path):
            os.makedirs(output_path)
            
        url = f"{self.auto_frp_backend_url}/config"
        data = {
            "platform": self.platform,
            "port": port
        }
        
        # 如果指定了远程端口，添加到请求数据中
        if remote_port is not None:
            data["remote_port"] = remote_port
        
        response = requests.post(url, json=data)
        
        if response.status_code != 200:
            error_msg = f"下载失败，状态码: {response.status_code}"
            try:
                error_data = response.json()
                if "error" in error_data:
                    error_msg += f", 错误: {error_data['error']}"
            except:
                pass
            raise Exception(error_msg)
        
        # 根据平台确定文件扩展名
        file_ext = "zip" if self.platform == "win" else "tar.gz"
        output_file = os.path.join(output_path, f"frpc.{file_ext}")
        
        with open(output_file, "wb") as f:
            f.write(response.content)
            
        return output_file
    
    def extract_config(self, file_path: str, extract_path: str = "./"):
        """
        解压下载的配置文件
        
        Args:
            file_path: 下载的压缩文件路径
            extract_path: 解压目标路径
            
        Returns:
            str: 解压后的frpc可执行文件路径
        """

        
        if not os.path.exists(extract_path):
            os.makedirs(extract_path)
            
        if self.platform == "win":

            with zipfile.ZipFile(file_path, 'r') as zip_ref:
                zip_ref.extractall(extract_path)
            return os.path.join(extract_path, "frpc.exe")
        else:

            with tarfile.open(file_path, 'r:gz') as tar_ref:
                tar_ref.extractall(extract_path)
            frpc_path = os.path.join(extract_path, "frpc")
            # 设置执行权限
            os.chmod(frpc_path, 0o755)
            return frpc_path
    
    def run_frpc(self, frpc_path: str, config_path: str = None, pre_command: str = "xinference-local --host 0.0.0.0 --port 9997 "):
        """
        后台运行frpc客户端并保活
        
        Args:
            frpc_path: frpc可执行文件路径
            config_path: 配置文件路径，默认为同目录下的frpc.toml
            pre_command: 在启动frpc前执行的命令
            
        Returns:
            dict: 包含进程信息和监控进程的字典
        """

        if config_path is None:
            config_path = os.path.join(os.path.dirname(frpc_path), "frpc.toml")
        
        # 在Linux上确保frpc有正确的执行权限
        if self.platform != "win" and os.path.exists(frpc_path):

            current_permissions = os.stat(frpc_path).st_mode
            os.chmod(frpc_path, current_permissions | stat.S_IXUSR | stat.S_IXGRP | stat.S_IXOTH)
        
        # 设置进程不显示窗口（仅在Windows上有效）
        startupinfo = None
        if self.platform == "win":

            startupinfo = subprocess.STARTUPINFO()
            startupinfo.dwFlags |= subprocess.STARTF_USESHOWWINDOW
            startupinfo.wShowWindow = 0  # SW_HIDE
        
        # 创建日志文件
        log_path = os.path.join(os.path.dirname(frpc_path), "frpc.log")
        log_file = open(log_path, "w")
        
        # 启动进程
        cmd = [frpc_path, "-c", config_path]
        if pre_command:
            # 构建含有 && 的命令字符串
            cmd_str = f"{pre_command} & {frpc_path} -c {config_path}"
            process = subprocess.Popen(
                cmd_str,
                stdout=log_file,
                stderr=log_file,
                startupinfo=startupinfo,
                creationflags=subprocess.CREATE_NEW_PROCESS_GROUP if self.platform == "win" else 0,
                shell=True
            )
        else:
            process = subprocess.Popen(
                cmd,
                stdout=log_file,
                stderr=log_file,
                startupinfo=startupinfo,
                creationflags=subprocess.CREATE_NEW_PROCESS_GROUP if self.platform == "win" else 0
            )
        
        # 创建保活监控线程
        stop_event = threading.Event()
        
        # 使用可变容器来存储进程引用，避免使用nonlocal
        process_container = {"instance": process}
        
        def keep_alive_monitor():
            while not stop_event.is_set():
                if process_container["instance"].poll() is not None:  # 进程已退出
                    try:
                        # 重新启动进程
                        if pre_command:
                            # 构建含有 && 的命令字符串
                            cmd_str = f"{pre_command} & {frpc_path} -c {config_path}"
                            new_process = subprocess.Popen(
                                cmd_str,
                                stdout=log_file,
                                stderr=log_file,
                                startupinfo=startupinfo,
                                creationflags=subprocess.CREATE_NEW_PROCESS_GROUP if self.platform == "win" else 0,
                                shell=True
                            )
                        else:
                            new_process = subprocess.Popen(
                                cmd,
                                stdout=log_file,
                                stderr=log_file,
                                startupinfo=startupinfo,
                                creationflags=subprocess.CREATE_NEW_PROCESS_GROUP if self.platform == "win" else 0
                            )
                        # 更新进程引用
                        process_container["instance"] = new_process
                        print(f"frpc进程已重启，新PID: {new_process.pid}")
                    except Exception as e:
                        print(f"重启frpc失败: {str(e)}")
                        
                time.sleep(5)  # 每5秒检查一次
        
        # 启动监控线程
        monitor_thread = threading.Thread(target=keep_alive_monitor, daemon=True)
        monitor_thread.start()
        
        # 注册清理函数
        def cleanup_handler():
            stop_event.set()  # 停止监控线程
            if process_container["instance"].poll() is None:  # 如果进程还在运行
                if self.platform == "win":
                    process_container["instance"].send_signal(signal.CTRL_BREAK_EVENT)
                else:
                    process_container["instance"].terminate()
                process_container["instance"].wait(timeout=5)
            log_file.close()

        try:
            # 堵塞主线程，直到捕获到键盘中断（Ctrl+C）
            print(f"frpc进程已启动，PID: {process.pid}，按Ctrl+C停止")
            while not stop_event.is_set():
                time.sleep(1)
        except KeyboardInterrupt:
            print("接收到停止信号，正在停止frpc...")
            cleanup_handler()
            print("frpc已停止")
        
        # 返回包含进程和控制对象的字典（为了保持与原接口兼容）
        return {
            "process": process,
            "stop_monitor": stop_event,
            "log_path": log_path,
            "cleanup": cleanup_handler
        }
    
    def setup_and_run(self, port: int, output_path: str = "./frpc", remote_port: int = None):
        """
        一键设置并运行frpc，此方法会堵塞当前线程直到手动中断（Ctrl+C）
        
        Args:
            port: 本地要映射的端口
            output_path: 保存和解压文件的路径
            remote_port: 可选的远程端口，如果不指定则由服务器随机分配
            pre_command: 在启动frpc前执行的命令，例如 "ollama serve && ollama pull bge-m3"
            
        Returns:
            dict: 包含frpc进程信息和控制函数的字典
        """
        print(f"正在设置映射本地端口 {port} 到 AutoFrp...")
        file_path = self.download_config(port, output_path, remote_port)
        print(f"配置已下载，正在解压...")
        frpc_path = self.extract_config(file_path, output_path)
        print(f"配置已解压，正在启动frpc服务...")
        # 这个调用会堵塞当前线程直到用户中断
        return self.run_frpc(frpc_path)

# %%
client=AutoFrp("http://117.158.43.187:28098/","linux")
client.setup_and_run(port=9997,output_path="./frpc_backend",remote_port=7899)
# Out:
# 正在设置映射本地端口 9997 到 AutoFrp...
# 配置已下载，正在解压...
# 配置已解压，正在启动frpc服务...
# frpc进程已启动，PID: 337，按Ctrl+C停止
